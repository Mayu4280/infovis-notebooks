# %% [markdown]
# # ノーベル賞受賞者のデータ
#
# Wikipediaからスクレイピングしてきたノーベル賞受賞者のデータを使って、データ可視化の6ステップのうち、前半の3ステップをたどります。
#
# 1. 問いの設定
# 2. データの用意
# 3. データの探索
#
# (---ここまで---)
#
# 4. 仮説の設定
# 5. データの分析
# 6. データの説明

# %%
# ライブラリをロードする
import pandas as pd
import numpy as np

# %% [markdown]
# ## 問いの設定

# %% [markdown]
# 歴代ノーベル賞受賞者の属性に共通するパターンはあるか？

# %% [markdown]
# ## データの用意
#
# この演習では、手元にすでにスクレイピング済みのデータがあると仮定します。
#
# PythonによるWebスクレイピングに有用なライブラリとして、下記があります。Webスクレイピングの例は[この演習](./web-scraping-tutorial.ipynb)で。
#
# * [requests](https://requests-docs-ja.readthedocs.io/en/latest/): HTTP通信用のライブラリ
# * [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/): XMLパース用のライブラリ
# * [Scrapy](https://scrapy.org/): スクレイピング、クローリング用のフレームワーク

# %%
# JSON形式のファイルを読み込む

import pandas as pd
file_url = "./data/nobel_winners_dirty.json"
df = pd.read_json(file_url)

# %% [markdown]
# JSONとは、JavaScript Object Notationの略で、以下のような形式のデータです。
#
# ```
# [
#   {
#     "born_in": "",
#     "category": "Physiology or Medicine",
#     "country": "Argentina",
#     "date_of_birth": "8 October 1927",
#     "date_of_death": "24 March 2002",
#     "gender": "male",
#     "link": "http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein",
#     "name": "César Milstein",
#     "place_of_birth": "Bahía Blanca ,  Argentina",
#     "place_of_death": "Cambridge , England",
#     "text": "César Milstein , Physiology or Medicine, 1984",
#     "year": 1984
#   },
#   {
#     "born_in": "Bosnia and Herzegovina",
#     "category": "Literature",
#     "country": "",
#     "date_of_birth": "9 October 1892",
#     "date_of_death": "13 March 1975",
#     "gender": "male",
#     "link": "http://en.wikipedia.org/wiki/Ivo_Andric",
#     "name": "Ivo Andric *",
#     "place_of_birth": "Dolac (village near Travnik), Austria-Hungary (present-day Bosnia and Herzegovina)",
#     "place_of_death": "Belgrade, SR Serbia, SFR Yugoslavia (present-day Serbia)",
#     "text": "Ivo Andric *,  born in then  Austria–Hungary , now Bosnia and Herzegovina , Literature, 1961",
#     "year": 1961
#   }
# ]
# ```

# %% [markdown]
# ### データの確認

# %%
# まずはデータの形をざっと確認

df.head()
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                          Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature             9 October 1892
# 2  Bosnia and Herzegovina               Chemistry              July 23, 1906
# 3                                           Peace    Belgium            None
# 4                                           Peace    Belgium    26 July 1829
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                               name  \
# 0                   César Milstein
# 1                     Ivo Andric *
# 2                Vladimir Prelog *
# 3  Institut de Droit International
# 4                Auguste Beernaert
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
# 2  Sarajevo ,  Bosnia and Herzegovina , then part...
# 3                                               None
# 4             Ostend ,  Netherlands  (now  Belgium )
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                              Zürich ,  Switzerland
# 3                                               None
# 4                             Lucerne ,  Switzerland
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# 1  Ivo Andric *,  born in then  Austria–Hungary ,...  1961
# 2  Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 3      Institut de Droit International , Peace, 1904  1904
# 4                    Auguste Beernaert , Peace, 1909  1909

# %%
# 列を見る

df.columns
# Out:
# Index(['born_in', 'category', 'country', 'date_of_birth', 'date_of_death',
#        'gender', 'link', 'name', 'place_of_birth', 'place_of_death', 'text',
#        'year'],
#       dtype='object')

# %%
# 行を見る

df.index
# Out:
# RangeIndex(start=0, stop=1052, step=1)

# %%
# 概要を見る

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %% [markdown]
# ここから、一部のフィールド（性別など）が欠損していることが分かります（1052行のところ、1044要素しかないなど）。
#
# また、読み込んだばかりの状態では、`year`のみが数値（`int64`）になっており、他の変数はオブジェクトとして扱われていることが分かります。オブジェクトはpandasのデフォルトのデータ型で、任意の数値、文字列、日時などを表すことができます。

# %%
# 要約統計量を見る

df.describe()
# Out:
#               year
# count  1052.000000
# mean   1968.729087
# std      33.155829
# min    1809.000000
# 25%    1947.000000
# 50%    1975.000000
# 75%    1996.000000
# max    2014.000000

# %% [markdown]
# 要約統計量は、デフォルトの状態では数値列だけが表示されます。
#
# 最小値は1809ですが、ノーベル賞の授与は1901年から始まったので明らかに正しくない数値が含まれていることが分かります。最大値は2014で、2014年までの受賞者が含まれているようです。
#
# `describe`にパラメータを与えることで、オブジェクトにもアクセスするように指定できます。

# %%
df.describe(include=["object"])
# Out:
#        born_in                category        country date_of_birth  \
# count     1052                    1052           1052          1044
# unique      40                       7             59           853
# top             Physiology or Medicine  United States    9 May 1947
# freq       910                     250            350             4
#
#        date_of_death gender                                      link  \
# count           1044   1040                                      1052
# unique           563      2                                       893
# top                    male  http://en.wikipedia.org/wiki/Marie_Curie
# freq             362    982                                         4
#
#                 name place_of_birth place_of_death  \
# count           1052           1044           1044
# unique           998            735            410
# top     Ronald Coase
# freq               2             29            409
#
#                                 text
# count                           1052
# unique                          1043
# top     Betty Williams , Peace, 1976
# freq                               2

# %% [markdown]
# ここから、受賞者には59の国籍があり、米国が350で最大のグループであるなどの情報が得られます。
#
# また、生年月日は全部で1044ありますが、異なり数は853であることが分かります。複数の受賞者が生まれた縁起の良い日があるか、受賞者のデータが重複している可能性があります。
#
# 氏名の異なり数が998というのも、受賞者のデータが重複している可能性を示すものです。2つ以上の賞を受賞している人は数名いますが（調べた限りでは4名）、54の重複はそれに対して多すぎます。
#
# [Multiple Nobel Prize laureates](https://www.nobelprize.org/prizes/facts/nobel-prize-facts/#:~:text=Linus%20Pauling%20is%20the%20only,the%201962%20Nobel%20Peace%20Prize.)

# %%
# もう一度、生データを確認

df.head(10)
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                          Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature             9 October 1892
# 2  Bosnia and Herzegovina               Chemistry              July 23, 1906
# 3                                           Peace    Belgium            None
# 4                                           Peace    Belgium    26 July 1829
# 5                                      Literature    Belgium  29 August 1862
# 6                                           Peace    Belgium   22 April 1854
# 7                          Physiology or Medicine    Belgium    13 June 1870
# 8                          Physiology or Medicine    Belgium   28 March 1892
# 9                                           Peace    Belgium      1910-02-10
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# 5      6 May 1949   male   http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# 6     14 May 1943   male     http://en.wikipedia.org/wiki/Henri_La_Fontaine
# 7    6 April 1961   male          http://en.wikipedia.org/wiki/Jules_Bordet
# 8    18 July 1968   male     http://en.wikipedia.org/wiki/Corneille_Heymans
# 9      1969-01-30   male          http://en.wikipedia.org/wiki/Georges_Pire
#
#                               name  \
# 0                   César Milstein
# 1                     Ivo Andric *
# 2                Vladimir Prelog *
# 3  Institut de Droit International
# 4                Auguste Beernaert
# 5              Maurice Maeterlinck
# 6                Henri La Fontaine
# 7                     Jules Bordet
# 8                Corneille Heymans
# 9                     Georges Pire
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
# 2  Sarajevo ,  Bosnia and Herzegovina , then part...
# 3                                               None
# 4             Ostend ,  Netherlands  (now  Belgium )
# 5                                   Ghent ,  Belgium
# 6                                           Brussels
# 7                                  Soignies, Belgium
# 8                                  Ghent ,  Flanders
# 9                                  Dinant ,  Belgium
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                              Zürich ,  Switzerland
# 3                                               None
# 4                             Lucerne ,  Switzerland
# 5                                     Nice ,  France
# 6                                            Belgium
# 7
# 8                                 Knokke ,  Flanders
# 9                                   Leuven , Belgium
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# 1  Ivo Andric *,  born in then  Austria–Hungary ,...  1961
# 2  Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 3      Institut de Droit International , Peace, 1904  1904
# 4                    Auguste Beernaert , Peace, 1909  1909
# 5             Maurice Maeterlinck , Literature, 1911  1911
# 6                    Henri La Fontaine , Peace, 1913  1913
# 7        Jules Bordet , Physiology or Medicine, 1919  1919
# 8   Corneille Heymans , Physiology or Medicine, 1938  1938
# 9                         Georges Pire , Peace, 1958  1958

# %%
df.tail(5)
# Out:
#      born_in                category    country      date_of_birth  \
# 1047                         Physics  Australia  February 24, 1967
# 1048                           Peace  Argentina   November 1, 1878
# 1049          Physiology or Medicine  Argentina         1887-04-10
# 1050                       Chemistry  Argentina           1906-9-6
# 1051                           Peace  Argentina  November 26, 1931
#
#      date_of_death gender                                               link  \
# 1047                 male      http://en.wikipedia.org/wiki/Brian_P._Schmidt
# 1048   May 5, 1959   male  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...
# 1049    1971-09-21   male      http://en.wikipedia.org/wiki/Bernardo_Houssay
# 1050     1987-12-2   male  http://en.wikipedia.org/wiki/Luis_Federico_Leloir
# 1051                 male  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...
#
#                        name             place_of_birth  \
# 1047       Brian P. Schmidt          Missoula, Montana
# 1048  Carlos Saavedra Lamas  Buenos Aires ,  Argentina
# 1049       Bernardo Houssay  Buenos Aires ,  Argentina
# 1050   Luis Federico Leloir            Paris ,  France
# 1051  Adolfo Pérez Esquivel               Buenos Aires
#
#                  place_of_death  \
# 1047
# 1048    Buenos Aires, Argentina
# 1049  Buenos Aires ,  Argentina
# 1050  Buenos Aires ,  Argentina
# 1051
#
#                                                    text  year
# 1047  Brian P. Schmidt ,  born in the United States ...  2011
# 1048                Carlos Saavedra Lamas , Peace, 1936  1936
# 1049    Bernardo Houssay , Physiology or Medicine, 1947  1947
# 1050             Luis Federico Leloir , Chemistry, 1970  1970
# 1051                Adolfo Pérez Esquivel , Peace, 1980  1980

# %% [markdown]
# よく見ると、名前の後ろにアスタリスクがついている人がいたり、生年月日のフォーマットが統一されていなかったり、`born_in`の情報がほぼ存在しない、といったことが分かります。

# %% [markdown]
# ここまでの情報をもとに、現時点でのデータ仕様書を作っておきましょう。
#
# 前処理が終わった後にデータ仕様書をアップデートします。

# %%
# 現時点のデータ仕様書を作る

# %% [markdown]
# | カラム | カラムの説明 | データ型 | データ型（理想） | 尺度 | 値の説明 | NULL | UNIQ | CHECK |
# |:--|:--|:--|:--|:--|:--|:--|:--|:--|
# | born_in | 出生地 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | category | 賞の種類 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  | |
# | country | 国籍 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | date_of_birth | 生年月日 | テキスト | 数値 | 間隔尺度 |  | ✔ |  |  |
# | date_of_death | 没年月日 | テキスト | 数値 | 間隔尺度 |  | ✔ |  |  |
# | gender | 性別 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | link | ウィキペディアへのリンク | テキスト | テキスト | テキスト |  | ✔ |  |  |
# | name | 氏名 | テキスト | テキスト | テキスト |  | ✔ |  |  |
# | place_of_birth | 出生地 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | place_of_death | 死没地 | テキスト | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | text | 説明 | テキスト | テキスト | テキスト |  | ✔ |  |  |
# | year | 受賞年 | 数値 | 数値 | 間隔尺度 |  | ✔ |  | 1901 $\leq$ x $\leq$ 2022 |
#
# * `NULL`: 欠損値が存在する可能性があるか
# * `UNIQ`: 重複しない値か
# * `CHECK`: 満たすべき条件

# %%
# データの前処理（欠損値、重複、整列されていない行、不統一、エラー値、データの混合などに対処する）
# born_in

# %% [markdown]
# まずは、ほぼ存在しない`born_in`を適切に欠損値として処理できるようにします。
#
# `apply`メソッドを使うと、セルに対して同じ処理を繰り返し実行できます。これを使って`born_in`の実際のデータ型（pandasのオブジェクトにラップされているもの）を見てみましょう。

# %%
df["born_in"].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 1047    <class 'str'>
# 1048    <class 'str'>
# 1049    <class 'str'>
# 1050    <class 'str'>
# 1051    <class 'str'>
# Name: born_in, Length: 1052, dtype: object

# %% [markdown]
# `set`を使って集合をとることで、異なり値だけを取り出します。

# %%
set(df["born_in"].apply(type))
# Out:
# {str}

# %% [markdown]
# すべてのデータがテキスト型であることが分かりました。何もないように見えるセルにも空白文字（スペース、タブ、改行など）が入っているようです。
#
# 空白文字を欠損値（`NaN`）に置換しましょう。

# %%
# !pip install numpy
import numpy as np
df["born_in"] = df["born_in"].replace("", np.nan)
# Out:
# Requirement already satisfied: numpy in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (2.1.3)

# %%
df["born_in"].count()
# Out:
# np.int64(142)

# %% [markdown]
# これで空白文字が欠損値に置換され、`born_in`の正しい数が分かるようになりました。
#
# 同じ要領で、データセット内のすべての空文字列を欠損値に置換します。

# %%
df.replace("", np.nan, inplace=True)

# %%
# name

# %% [markdown]
# さきほど、アスタリスクが付いた名前がありました。これを整えていきます。
#
# まず、アスタリスクが付いた名前の数を調べます。

# %%
set(df["name"].apply(type))
# Out:
# {str}

# %% [markdown]
# `name`も文字列ということが分かります。
#
# `name`に`*`が含まれているセルを`str.contains()`で見てみます。
#
# `\\*`という風にアスタリスクの前にバックスラッシュをつけるのは、アスタリスクを正規表現の記号（直前の文字の0回以上の繰り返し）ではなく、通常の文字としてのアスタリスクとして扱うためです。これを「エスケープする」と言います。
#
# [正規表現](https://ja.wikipedia.org/wiki/%E6%AD%A3%E8%A6%8F%E8%A1%A8%E7%8F%BE)

# %%
df["name"].str.contains("\\*")
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1047    False
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# Name: name, Length: 1052, dtype: bool

# %% [markdown]
# アスタリスクが付いている名前が`True`判定されています。
#
# これをデータフレームに代入し、`name`列だけを取り出すことができます。

# %%
df[df["name"].str.contains("\\*")]["name"]
# Out:
# 1                   Ivo Andric *
# 2              Vladimir Prelog *
# 14               Simon Kuznets *
# 15              Menachem Begin *
# 16                Shimon Peres *
#                   ...
# 1034            Martin Karplus *
# 1035    William Lawrence Bragg *
# 1039    Aleksandr M. Prokhorov *
# 1041     John Warcup Cornforth *
# 1046    Elizabeth H. Blackburn *
# Name: name, Length: 142, dtype: object

# %% [markdown]
# 142個ありました。
#
# 把握できたところで、アスタリスクを置換し、前後の空白も取ります。
#
# 置換には`str.replace()`、前後の空白削除には`str.strip()`を使います。

# %%
df["name"] = df["name"].str.replace('*', '', regex=False) #regex=Falseで、文字列をそのまま扱う

# %%
df["name"] = df["name"].str.strip()

# %%
df[df.name.str.contains("\\*")]["name"]
# Out:
# Series([], Name: name, dtype: object)

# %% [markdown]
# 再度数えてみると、アスタリスク付きの名前がなくなっていることが分かります。

# %%
df[df["name"].str.contains("\\*")]["name"]
# Out:
# Series([], Name: name, dtype: object)

# %%
# 重複

# %% [markdown]
# 次に、重複しているデータに対処します。`duplicated`メソッドで重複している行が`True`と判定されます。

# %%
df.duplicated("name", keep=False)
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1047     True
# 1048    False
# 1049    False
# 1050     True
# 1051    False
# Length: 1052, dtype: bool

# %% [markdown]
# これをデータセット全体の条件にすると、氏名が重複している行のみを抽出できます。

# %%
all_dupes = df[df.duplicated("name", keep=False)]

# %%
all_dupes
# Out:
#                      born_in                category    country  \
# 0                        NaN  Physiology or Medicine  Argentina
# 2     Bosnia and Herzegovina               Chemistry        NaN
# 11                       NaN  Physiology or Medicine    Belgium
# 12                       NaN               Chemistry    Belgium
# 14                   Belarus               Economics        NaN
# ...                      ...                     ...        ...
# 1039               Australia                 Physics        NaN
# 1040                     NaN              Literature  Australia
# 1042                     NaN               Economics  Australia
# 1047                     NaN                 Physics  Australia
# 1050                     NaN               Chemistry  Argentina
#
#           date_of_birth      date_of_death gender  \
# 0        8 October 1927      24 March 2002   male
# 2         July 23, 1906         1998-01-07   male
# 11       2 October 1917         4 May 2013   male
# 12      25 January 1917        28 May 2003   male
# 14       April 30, 1901       July 8, 1985   male
# ...                 ...                ...    ...
# 1039       11 July 1916     8 January 2002   male
# 1040        28 May 1912  30 September 1990   male
# 1042       May 29, 1920     August 9, 2000   male
# 1047  February 24, 1967                NaN   male
# 1050           1906-9-6          1987-12-2   male
#
#                                                    link  \
# 0      http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 2          http://en.wikipedia.org/wiki/Vladimir_Prelog
# 11       http://en.wikipedia.org/wiki/Christian_de_Duve
# 12          http://en.wikipedia.org/wiki/Ilya_Prigogine
# 14           http://en.wikipedia.org/wiki/Simon_Kuznets
# ...                                                 ...
# 1039  http://en.wikipedia.org/wiki/Aleksandr_M._Prok...
# 1040         http://en.wikipedia.org/wiki/Patrick_White
# 1042         http://en.wikipedia.org/wiki/John_Harsanyi
# 1047      http://en.wikipedia.org/wiki/Brian_P._Schmidt
# 1050  http://en.wikipedia.org/wiki/Luis_Federico_Leloir
#
#                         name  \
# 0             César Milstein
# 2            Vladimir Prelog
# 11         Christian de Duve
# 12            Ilya Prigogine
# 14             Simon Kuznets
# ...                      ...
# 1039  Aleksandr M. Prokhorov
# 1040           Patrick White
# 1042           John Harsanyi
# 1047        Brian P. Schmidt
# 1050    Luis Federico Leloir
#
#                                          place_of_birth  \
# 0                             Bahía Blanca ,  Argentina
# 2     Sarajevo ,  Bosnia and Herzegovina , then part...
# 11                Thames Ditton, Surrey, United Kingdom
# 12                                     Moscow ,  Russia
# 14                                                Pinsk
# ...                                                 ...
# 1039                  Atherton, Queensland ,  Australia
# 1040                             Knightsbridge , London
# 1042                                Budapest ,  Hungary
# 1047                                  Missoula, Montana
# 1050                                    Paris ,  France
#
#                    place_of_death  \
# 0             Cambridge , England
# 2           Zürich ,  Switzerland
# 11          Grez-Doiceau, Belgium
# 12            Brussels ,  Belgium
# 14       Cambridge, Massachusetts
# ...                           ...
# 1039             Moscow ,  Russia
# 1040            Sydney, Australia
# 1042  Berkeley, California ,  USA
# 1047                          NaN
# 1050    Buenos Aires ,  Argentina
#
#                                                    text  year
# 0         César Milstein , Physiology or Medicine, 1984  1984
# 2     Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 11    Christian de Duve ,  born in the United Kingdo...  1974
# 12    Ilya Prigogine ,  born in Russia , Chemistry, ...  1977
# 14    Simon Kuznets *,  born in then Russian Empire,...  1971
# ...                                                 ...   ...
# 1039            Aleksandr M. Prokhorov *, Physics, 1964  1964
# 1040  Patrick White ,  born in the United Kingdom , ...  1973
# 1042                    John Harsanyi , Economics, 1994  1994
# 1047  Brian P. Schmidt ,  born in the United States ...  2011
# 1050             Luis Federico Leloir , Chemistry, 1970  1970
#
# [299 rows x 12 columns]

# %% [markdown]
# 299行の重複があることが分かりました。重複行を名前で並べ替え、国籍と受賞年を見てみます。

# %%
all_dupes.sort_values("name")[["born_in", "name", "country", "year"]]
# Out:
#           born_in                      name         country  year
# 131           NaN                Aaron Klug  United Kingdom  1982
# 121           NaN                Aaron Klug    South Africa  1982
# 106     Lithuania                Aaron Klug             NaN  1982
# 440           NaN           Alan MacDiarmid   United States  2000
# 742   New Zealand           Alan MacDiarmid             NaN  2000
# ...           ...                       ...             ...   ...
# 417           NaN           William Vickrey   United States  1996
# 489           NaN            Yoichiro Nambu   United States  2008
# 773           NaN            Yoichiro Nambu           Japan  2008
# 1010      Belarus  Zhores Ivanovich Alferov             NaN  2000
# 692           NaN  Zhores Ivanovich Alferov          Russia  2000
#
# [299 rows x 4 columns]

# %% [markdown]
# 同じ年の受賞で異なる国籍になっている人がいますし、国籍が欠損している場合もあります。
#
# 今回参照したWikipediaでは、国ごとに受賞者のリストが作られているので、受賞者が別の国に移住した場合などは移住前後の国の両方が書かれているようです。
#
# また、国籍が欠損してる場合は、`born_in`に国名が入っているようです。

# %% [markdown]
# ここではまず、`born_in`の情報を失くさないために同一受賞者の欠損箇所にコピーします。

# %%
# 表示できる行数を増やす
pd.set_option('display.max_rows', 300)

# %% [markdown]
# `born_in`が欠損していない行のリストを作ります。

# %%
bi_df = all_dupes[~all_dupes["born_in"].isna()]

# %%
bi_df.head()
# Out:
#                    born_in   category country   date_of_birth  date_of_death  \
# 2   Bosnia and Herzegovina  Chemistry     NaN   July 23, 1906     1998-01-07
# 14                 Belarus  Economics     NaN  April 30, 1901   July 8, 1985
# 15                 Belarus      Peace     NaN  16 August 1913   9 March 1992
# 16                 Belarus      Peace     NaN   2 August 1923            NaN
# 27          Czech Republic      Peace     NaN    June 9, 1843  June 21, 1914
#
#     gender                                             link  \
# 2     male     http://en.wikipedia.org/wiki/Vladimir_Prelog
# 14    male       http://en.wikipedia.org/wiki/Simon_Kuznets
# 15    male      http://en.wikipedia.org/wiki/Menachem_Begin
# 16    male        http://en.wikipedia.org/wiki/Shimon_Peres
# 27  female  http://en.wikipedia.org/wiki/Bertha_von_Suttner
#
#                   name                                     place_of_birth  \
# 2      Vladimir Prelog  Sarajevo ,  Bosnia and Herzegovina , then part...
# 14       Simon Kuznets                                              Pinsk
# 15      Menachem Begin                            Brest ,  Russian Empire
# 16        Shimon Peres                                             Poland
# 27  Bertha von Suttner                          Prague ,  Austrian Empire
#
#                place_of_death  \
# 2       Zürich ,  Switzerland
# 14   Cambridge, Massachusetts
# 15          Tel Aviv , Israel
# 16                        NaN
# 27  Vienna ,  Austria-Hungary
#
#                                                  text  year
# 2   Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 14  Simon Kuznets *,  born in then Russian Empire,...  1971
# 15  Menachem Begin *,  born in then Russian Empire...  1978
# 16  Shimon Peres *,  born in then Poland, now Bela...  1994
# 27  Bertha von Suttner *,  born in then Austrian-H...  1905

# %% [markdown]
# bi_dfに含まれている受賞者を全体から取り出し、`name`と`born_in`で並べ替えます。こうすることで、必ず同一人物の`born_in`が欠損しているデータが欠損していないデータのすぐ後にくることになります。

# %%
df[["born_in", "name"]][df["name"].isin(bi_df["name"])].sort_values(["name", "born_in"])
# Out:
#                      born_in                        name
# 106                Lithuania                  Aaron Klug
# 121                      NaN                  Aaron Klug
# 131                      NaN                  Aaron Klug
# 742              New Zealand             Alan MacDiarmid
# 440                      NaN             Alan MacDiarmid
# 870                  Germany           Albert Schweitzer
# 38                       NaN           Albert Schweitzer
# 1039               Australia      Aleksandr M. Prokhorov
# 680                      NaN      Aleksandr M. Prokhorov
# 694                   Russia         Alexei A. Abrikosov
# 458                      NaN         Alexei A. Abrikosov
# 924                   France               Alfred Werner
# 612                      NaN               Alfred Werner
# 120             South Africa            Allan M. Cormack
# 360                      NaN            Allan M. Cormack
# 697                   Russia                  Andre Geim
# 97                       NaN                  Andre Geim
# 104                Lithuania              Andrew Schally
# 712                   Poland              Andrew Schally
# 588           United Kingdom          Anthony J. Leggett
# 460                      NaN          Anthony J. Leggett
# 51                   Germany                Arno Penzias
# 356                      NaN                Arno Penzias
# 887                  Germany                Bernard Katz
# 561                      NaN                Bernard Katz
# 27            Czech Republic          Bertha von Suttner
# 1014                     NaN          Bertha von Suttner
# 704                 Portugal  Carlos Filipe Ximenes Belo
# 968                      NaN  Carlos Filipe Ximenes Belo
# 989                   Canada          Charles B. Huggins
# 320                      NaN          Charles B. Huggins
# 980                    China              Charles K. Kao
# 498                      NaN              Charles K. Kao
# 831                      NaN              Charles K. Kao
# 571           United Kingdom           Christian de Duve
# 11                       NaN           Christian de Duve
# 105                Lithuania              Czesław Miłosz
# 714                   Poland              Czesław Miłosz
# 194                      NaN              Czesław Miłosz
# 978                    China              Daniel C. Tsui
# 430                      NaN              Daniel C. Tsui
# 992                   Canada              David H. Hubel
# 199                      NaN              David H. Hubel
# 807                  Ireland               David Trimble
# 581                      NaN               David Trimble
# 1008                Bulgaria               Elias Canetti
# 129                      NaN               Elias Canetti
# 699                  Romania                 Elie Wiesel
# 378                      NaN                 Elie Wiesel
# 1031                 Austria              Eric R. Kandel
# 435                      NaN              Eric R. Kandel
# 740              New Zealand           Ernest Rutherford
# 524                      NaN           Ernest Rutherford
# 985                      NaN           Ernest Rutherford
# 866                  Germany           Ernst Boris Chain
# 155                      NaN           Ernst Boris Chain
# 825                  Hungary               Eugene Wigner
# 311                      NaN               Eugene Wigner
# 666                 Slovenia              Friderik Pregl
# 1017                     NaN              Friderik Pregl
# 102               Luxembourg            Gabriel Lippmann
# 917                      NaN            Gabriel Lippmann
# 979                    China                Gao Xingjian
# 948                      NaN                Gao Xingjian
# 698                  Romania            George E. Palade
# 334                      NaN            George E. Palade
# 717                   Poland             Georges Charpak
# 604                  Ukraine             Georges Charpak
# 945                      NaN             Georges Charpak
# 889                  Germany            Gerhard Herzberg
# 990                      NaN            Gerhard Herzberg
# 28            Czech Republic                  Gerty Cori
# 265                      NaN                  Gerty Cori
# 897                  Germany               Günter Blobel
# 433                      NaN               Günter Blobel
# 871                  Germany            Hans Adolf Krebs
# 543                      NaN            Hans Adolf Krebs
# 63                   Germany             Hans G. Dehmelt
# 394                      NaN             Hans G. Dehmelt
# 852                  Germany      Hans von Euler-Chelpin
# 643                      NaN      Hans von Euler-Chelpin
# 50                   Germany             Henry Kissinger
# 332                      NaN             Henry Kissinger
# 993                   Canada                 Henry Taube
# 369                      NaN                 Henry Taube
# 700                  Romania                Herta Müller
# 904                      NaN                Herta Müller
# 600                  Ukraine       Ilya Ilyich Mechnikov
# 671                      NaN       Ilya Ilyich Mechnikov
# 687                   Russia              Ilya Prigogine
# 12                       NaN              Ilya Prigogine
# 713                   Poland       Isaac Bashevis Singer
# 358                      NaN       Isaac Bashevis Singer
# 673                   Russia                  Ivan Bunin
# 934                      NaN                  Ivan Bunin
# 667                   Serbia                  Ivo Andrić
# 225                      NaN                  Ivo Andrić
# 58                   Germany            Jack Steinberger
# 388                      NaN            Jack Steinberger
# 827                  Hungary               John Harsanyi
# 1042                     NaN               John Harsanyi
# 514            United States                John O'Keefe
# 599                      NaN                John O'Keefe
# 719                   Poland              Joseph Rotblat
# 140                      NaN              Joseph Rotblat
# 703                 Portugal            José Ramos-Horta
# 967                      NaN            José Ramos-Horta
# 103               Luxembourg           Jules A. Hoffmann
# 954                      NaN           Jules A. Hoffmann
# 881                  Germany                Konrad Bloch
# 313                      NaN                Konrad Bloch
# 696                   Russia        Konstantin Novoselov
# 595                      NaN        Konstantin Novoselov
# 695                   Russia              Leonid Hurwicz
# 488                      NaN              Leonid Hurwicz
# 721                      NaN              Leonid Hurwicz
# 972                  Croatia             Leopold Ružička
# 617                      NaN             Leopold Ružička
# 935                   France        Luis Federico Leloir
# 1050                     NaN        Luis Federico Leloir
# 879                  Germany        Maria Goeppert-Mayer
# 312                      NaN        Maria Goeppert-Mayer
# 1034                 Austria              Martin Karplus
# 174                      NaN              Martin Karplus
# 741              New Zealand             Maurice Wilkins
# 551                      NaN             Maurice Wilkins
# 875                  Germany                    Max Born
# 545                      NaN                    Max Born
# 886                  Germany                Max Delbrück
# 219                      NaN                Max Delbrück
# 15                   Belarus              Menachem Begin
# 688                   Russia              Menachem Begin
# 90                       NaN              Menachem Begin
# 797                   Israel              Michael Levitt
# 128             South Africa              Michael Levitt
# 175                      NaN              Michael Levitt
# 598                      NaN              Michael Levitt
# 138           United Kingdom               Michael Smith
# 998                      NaN               Michael Smith
# 1002                  Canada               Myron Scholes
# 424                      NaN               Myron Scholes
# 883                  Germany                 Nelly Sachs
# 649                      NaN                 Nelly Sachs
# 756              Netherlands        Nicolaas Bloembergen
# 201                      NaN        Nicolaas Bloembergen
# 135           United Kingdom             Niels Kaj Jerne
# 25                       NaN             Niels Kaj Jerne
# 962            Faroe Islands         Niels Ryberg Finsen
# 969                      NaN         Niels Ryberg Finsen
# 591           United Kingdom             Oliver Smithies
# 483                      NaN             Oliver Smithies
# 864                  Germany                  Otto Stern
# 253                      NaN                  Otto Stern
# 567           United Kingdom               Patrick White
# 1040                     NaN               Patrick White
# 1009                  Brazil               Peter Medawar
# 550                      NaN               Peter Medawar
# 82                     Italy             Renato Dulbecco
# 337                      NaN             Renato Dulbecco
# 87                     Italy           Riccardo Giacconi
# 452                      NaN           Riccardo Giacconi
# 821                  Hungary     Richard Adolf Zsigmondy
# 1018                     NaN     Richard Adolf Zsigmondy
# 1024                 Austria                Richard Kuhn
# 861                      NaN                Richard Kuhn
# 715                   Poland              Roald Hoffmann
# 603                  Ukraine              Roald Hoffmann
# 203                      NaN              Roald Hoffmann
# 820                  Hungary               Robert Bárány
# 1016                     NaN               Robert Bárány
# 938                   France             Roger Guillemin
# 351                      NaN             Roger Guillemin
# 997                   Canada           Rudolph A. Marcus
# 409                      NaN           Rudolph A. Marcus
# 794                    Italy              Salvador Luria
# 217                      NaN              Salvador Luria
# 991                   Canada                 Saul Bellow
# 346                      NaN                 Saul Bellow
# 601                  Ukraine           Selman A. Waksman
# 276                      NaN           Selman A. Waksman
# 115                    Spain                Severo Ochoa
# 299                      NaN                Severo Ochoa
# 937                   France               Seán MacBride
# 803                      NaN               Seán MacBride
# 16                   Belarus                Shimon Peres
# 718                   Poland                Shimon Peres
# 91                       NaN                Shimon Peres
# 602                  Ukraine          Shmuel Yosef Agnon
# 89                       NaN          Shmuel Yosef Agnon
# 14                   Belarus               Simon Kuznets
# 322                      NaN               Simon Kuznets
# 701                  Romania                 Stefan Hell
# 906                      NaN                 Stefan Hell
# 814                    India  Subrahmanyan Chandrasekhar
# 207                      NaN  Subrahmanyan Chandrasekhar
# 126             South Africa              Sydney Brenner
# 451                      NaN              Sydney Brenner
# 586                      NaN              Sydney Brenner
# 711                   Poland           Tadeus Reichstein
# 621                      NaN           Tadeus Reichstein
# 816                    India    Venkatraman Ramakrishnan
# 501                      NaN    Venkatraman Ramakrishnan
# 2     Bosnia and Herzegovina             Vladimir Prelog
# 624                      NaN             Vladimir Prelog
# 1030                 Austria                 Walter Kohn
# 432                      NaN                 Walter Kohn
# 109                   Latvia             Wilhelm Ostwald
# 672                   Russia             Wilhelm Ostwald
# 77                       NaN             Wilhelm Ostwald
# 1005                  Canada            Willard S. Boyle
# 499                      NaN            Willard S. Boyle
# 987                   Canada             William Giauque
# 270                      NaN             William Giauque
# 1035               Australia      William Lawrence Bragg
# 525                      NaN      William Lawrence Bragg
# 1001                  Canada             William Vickrey
# 417                      NaN             William Vickrey
# 1010                 Belarus    Zhores Ivanovich Alferov
# 692                      NaN    Zhores Ivanovich Alferov

# %% [markdown]
# `fillna(method="ffill")`で、直前の値で欠損値を埋めます。

# %%
df[["born_in", "name"]][df["name"].isin(bi_df["name"])].sort_values(["name", "born_in"]).fillna(method="ffill")
# Out:
# /tmp/ipykernel_33762/3653452117.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[["born_in", "name"]][df["name"].isin(bi_df["name"])].sort_values(["name", "born_in"]).fillna(method="ffill")
#                      born_in                        name
# 106                Lithuania                  Aaron Klug
# 121                Lithuania                  Aaron Klug
# 131                Lithuania                  Aaron Klug
# 742              New Zealand             Alan MacDiarmid
# 440              New Zealand             Alan MacDiarmid
# 870                  Germany           Albert Schweitzer
# 38                   Germany           Albert Schweitzer
# 1039               Australia      Aleksandr M. Prokhorov
# 680                Australia      Aleksandr M. Prokhorov
# 694                   Russia         Alexei A. Abrikosov
# 458                   Russia         Alexei A. Abrikosov
# 924                   France               Alfred Werner
# 612                   France               Alfred Werner
# 120             South Africa            Allan M. Cormack
# 360             South Africa            Allan M. Cormack
# 697                   Russia                  Andre Geim
# 97                    Russia                  Andre Geim
# 104                Lithuania              Andrew Schally
# 712                   Poland              Andrew Schally
# 588           United Kingdom          Anthony J. Leggett
# 460           United Kingdom          Anthony J. Leggett
# 51                   Germany                Arno Penzias
# 356                  Germany                Arno Penzias
# 887                  Germany                Bernard Katz
# 561                  Germany                Bernard Katz
# 27            Czech Republic          Bertha von Suttner
# 1014          Czech Republic          Bertha von Suttner
# 704                 Portugal  Carlos Filipe Ximenes Belo
# 968                 Portugal  Carlos Filipe Ximenes Belo
# 989                   Canada          Charles B. Huggins
# 320                   Canada          Charles B. Huggins
# 980                    China              Charles K. Kao
# 498                    China              Charles K. Kao
# 831                    China              Charles K. Kao
# 571           United Kingdom           Christian de Duve
# 11            United Kingdom           Christian de Duve
# 105                Lithuania              Czesław Miłosz
# 714                   Poland              Czesław Miłosz
# 194                   Poland              Czesław Miłosz
# 978                    China              Daniel C. Tsui
# 430                    China              Daniel C. Tsui
# 992                   Canada              David H. Hubel
# 199                   Canada              David H. Hubel
# 807                  Ireland               David Trimble
# 581                  Ireland               David Trimble
# 1008                Bulgaria               Elias Canetti
# 129                 Bulgaria               Elias Canetti
# 699                  Romania                 Elie Wiesel
# 378                  Romania                 Elie Wiesel
# 1031                 Austria              Eric R. Kandel
# 435                  Austria              Eric R. Kandel
# 740              New Zealand           Ernest Rutherford
# 524              New Zealand           Ernest Rutherford
# 985              New Zealand           Ernest Rutherford
# 866                  Germany           Ernst Boris Chain
# 155                  Germany           Ernst Boris Chain
# 825                  Hungary               Eugene Wigner
# 311                  Hungary               Eugene Wigner
# 1001                  Canada             William Vickrey
# 417                   Canada             William Vickrey
# 1010                 Belarus    Zhores Ivanovich Alferov
# 692                  Belarus    Zhores Ivanovich Alferov

# %% [markdown]
# 再度インデックス順に並べ替え、元のデータフレームに代入します。

# %%
df.loc[df[df["name"].isin(bi_df["name"])].index, ["born_in", "name"]] = df[["born_in", "name"]][df["name"].isin(bi_df["name"])].sort_values(["name", "born_in"]).ffill().sort_index()

# %%
df.describe(include=["object"])
# Out:
#         born_in                category        country    date_of_birth  \
# count       250                    1046            910             1043
# unique       39                       6             58              852
# top     Germany  Physiology or Medicine  United States  7 November 1867
# freq         38                     250            350                4
#
#        date_of_death gender                                      link  \
# count            682   1040                                      1052
# unique           562      2                                       893
# top      4 July 1934   male  http://en.wikipedia.org/wiki/Marie_Curie
# freq               4    982                                         4
#
#                   name place_of_birth place_of_death  \
# count             1052           1015            635
# unique             896            734            409
# top     Michael Levitt  New York City  Paris, France
# freq                 4             12             12
#
#                                 text
# count                           1052
# unique                          1043
# top     Betty Williams , Peace, 1976
# freq                               2

# %% [markdown]
# `born_in`の値が250個になりました。
#
# `all_dupes`を作り直します。

# %%
all_dupes = df[df.duplicated("name", keep=False)]

# %%
all_dupes.sort_values(["name", "born_in"])[["born_in", "name", "country", "year"]]
# Out:
#                      born_in                        name         country  year
# 106                Lithuania                  Aaron Klug             NaN  1982
# 121                Lithuania                  Aaron Klug    South Africa  1982
# 131                Lithuania                  Aaron Klug  United Kingdom  1982
# 440              New Zealand             Alan MacDiarmid   United States  2000
# 742              New Zealand             Alan MacDiarmid             NaN  2000
# 615                      NaN             Albert Einstein     Switzerland  1921
# 844                      NaN             Albert Einstein         Germany  1921
# 38                   Germany           Albert Schweitzer          France  1952
# 870                  Germany           Albert Schweitzer             NaN  1952
# 680                Australia      Aleksandr M. Prokhorov          Russia  1964
# 1039               Australia      Aleksandr M. Prokhorov             NaN  1964
# 458                   Russia         Alexei A. Abrikosov   United States  2003
# 694                   Russia         Alexei A. Abrikosov             NaN  2003
# 612                   France               Alfred Werner     Switzerland  1913
# 924                   France               Alfred Werner             NaN  1913
# 120             South Africa            Allan M. Cormack             NaN  1979
# 360             South Africa            Allan M. Cormack   United States  1979
# 97                    Russia                  Andre Geim     Netherlands  2010
# 697                   Russia                  Andre Geim             NaN  2010
# 104                Lithuania              Andrew Schally             NaN  1977
# 712                   Poland              Andrew Schally             NaN  1976
# 460           United Kingdom          Anthony J. Leggett   United States  2003
# 588           United Kingdom          Anthony J. Leggett             NaN  2003
# 176                      NaN               Arieh Warshel   United States  2013
# 798                      NaN               Arieh Warshel          Israel  2013
# 51                   Germany                Arno Penzias             NaN  1978
# 356                  Germany                Arno Penzias   United States  1978
# 94                       NaN               Avram Hershko          Israel  2004
# 830                      NaN               Avram Hershko         Hungary  2004
# 228                      NaN            Baruj Benacerraf       Venezuela  1980
# 366                      NaN            Baruj Benacerraf   United States  1980
# 561                  Germany                Bernard Katz  United Kingdom  1970
# 207                    India  Subrahmanyan Chandrasekhar   United States  1983
# 814                    India  Subrahmanyan Chandrasekhar             NaN  1983
# 126             South Africa              Sydney Brenner             NaN  2002
# 451             South Africa              Sydney Brenner   United States  2002
# 586             South Africa              Sydney Brenner  United Kingdom  2002
# 621                   Poland           Tadeus Reichstein     Switzerland  1950
# 711                   Poland           Tadeus Reichstein             NaN  1950
# 172                      NaN            Thomas C. Südhof   United States  2013
# 905                      NaN            Thomas C. Südhof         Germany  2013
# 294                      NaN               Tsung-Dao Lee   United States  1957
# 975                      NaN               Tsung-Dao Lee           China  1957
# 501                    India    Venkatraman Ramakrishnan   United States  2009
# 816                    India    Venkatraman Ramakrishnan             NaN  2009
# 2     Bosnia and Herzegovina             Vladimir Prelog             NaN  1975
# 624   Bosnia and Herzegovina             Vladimir Prelog     Switzerland  1975
# 432                  Austria                 Walter Kohn   United States  1998
# 1030                 Austria                 Walter Kohn             NaN  1998
# 333                      NaN            Wassily Leontief   United States  1973
# 684                      NaN            Wassily Leontief          Russia  1973
# 109                   Latvia             Wilhelm Ostwald             NaN  1909
# 77                    Russia             Wilhelm Ostwald         Germany  1909
# 672                   Russia             Wilhelm Ostwald             NaN  1909
# 499                   Canada            Willard S. Boyle   United States  2009
# 1005                  Canada            Willard S. Boyle             NaN  2009
# 270                   Canada             William Giauque   United States  1949
# 987                   Canada             William Giauque             NaN  1949
# 525                Australia      William Lawrence Bragg  United Kingdom  1915
# 1035               Australia      William Lawrence Bragg             NaN  1915
# 417                   Canada             William Vickrey   United States  1996
# 1001                  Canada             William Vickrey             NaN  1996
# 489                      NaN              Yoichiro Nambu   United States  2008
# 773                      NaN              Yoichiro Nambu           Japan  2008
# 692                  Belarus    Zhores Ivanovich Alferov          Russia  2000
# 1010                 Belarus    Zhores Ivanovich Alferov             NaN  2000

# %% [markdown]
# `all_dupes`のうち、国籍が欠損しているデータは削除しても構わないようになったので、削除します。

# %%
remove_index = all_dupes[all_dupes["country"].isna()].index

# %%
df = df.drop(remove_index)

# %%
df.describe(include=["object"])
# Out:
#         born_in                category        country    date_of_birth  \
# count       139                     938            910              932
# unique       37                       6             58              852
# top     Germany  Physiology or Medicine  United States  7 November 1867
# freq         21                     222            350                4
#
#        date_of_death gender                                      link  \
# count            611    931                                       941
# unique           562      2                                       888
# top      4 July 1934   male  http://en.wikipedia.org/wiki/Marie_Curie
# freq               4    878                                         4
#
#                     name place_of_birth place_of_death  \
# count                941            906            568
# unique               895            734            409
# top     Linus C. Pauling  New York City  Paris, France
# freq                   2             11             11
#
#                                                      text
# count                                                 941
# unique                                                933
# top     Michael Levitt ,  born in South Africa , Chemi...
# freq                                                    2

# %% [markdown]
# 受賞者数が941人になりました。まだ重複が国籍違いによる重複が解消されていないためです。

# %%
all_dupes = df[df.duplicated("name", keep=False)]

# %%
all_dupes.sort_values(["name", "born_in"])[["born_in", "name", "country", "year"]]
# Out:
#            born_in                      name         country  year
# 121      Lithuania                Aaron Klug    South Africa  1982
# 947            NaN  Médecins Sans Frontières          France  1999
# 490            NaN           Osamu Shimomura   United States  2008
# 776            NaN           Osamu Shimomura           Japan  2008
# 72             NaN            Philipp Lenard         Germany  1905
# 1013           NaN            Philipp Lenard         Austria  1905
# 650            NaN             Ragnar Granit          Sweden  1967
# 960            NaN             Ragnar Granit         Finland  1809
# 510            NaN         Ralph M. Steinman   United States  2011
# 1006           NaN         Ralph M. Steinman          Canada  2011
# 85             NaN      Rita Levi-Montalcini           Italy  1986
# 376            NaN      Rita Levi-Montalcini   United States  1986
# 96             NaN             Robert Aumann          Israel  2005
# 476            NaN             Robert Aumann   United States  2005
# 137            NaN              Ronald Coase  United Kingdom  1991
# 405            NaN              Ronald Coase   United States  1991
# 515            NaN            Shuji Nakamura   United States  2014
# 780            NaN            Shuji Nakamura           Japan  2014
# 396            NaN             Sidney Altman   United States  1990
# 995            NaN             Sidney Altman          Canada  1989
# 451   South Africa            Sydney Brenner   United States  2002
# 586   South Africa            Sydney Brenner  United Kingdom  2002
# 172            NaN          Thomas C. Südhof   United States  2013
# 905            NaN          Thomas C. Südhof         Germany  2013
# 294            NaN             Tsung-Dao Lee   United States  1957
# 975            NaN             Tsung-Dao Lee           China  1957
# 333            NaN          Wassily Leontief   United States  1973
# 684            NaN          Wassily Leontief          Russia  1973
# 489            NaN            Yoichiro Nambu   United States  2008
# 773            NaN            Yoichiro Nambu           Japan  2008

# %% [markdown]
# また、よく見ると
#
# * キュリー夫人の名前が2種類（Marie Curie、Marie Skłodowska-Curie）ある
# * Ragnar Granitが1809年に受賞されたことになっている（ノーベル賞は1901年開始）
# * Sidney Altmanは一度しか受賞されていないはずなのに、受賞年がずれている
#
# ことが分かります。
#
# ここは一つずつ修正します。

# %%
df.drop(df[df["year"] == 1809].index, inplace=True)

# %%
df = df[~(df["name"] == "Marie Curie")]

# %%
df.loc[(df["name"] == "Marie Skłodowska-Curie") & (df["year"] == 1911), "country"] = "France"

# %%
df = df[~((df["name"] == "Sidney Altman") & (df["year"] == 1990))]

# %%
all_dupes = df[df.duplicated("name", keep=False)]

# %%
all_dupes.sort_values(["name", "born_in"])[["born_in", "name", "country", "year"]]
# Out:
#            born_in                      name         country  year
# 121      Lithuania                Aaron Klug    South Africa  1982
# 131      Lithuania                Aaron Klug  United Kingdom  1982
# 615            NaN           Albert Einstein     Switzerland  1921
# 844            NaN           Albert Einstein         Germany  1921
# 176            NaN             Arieh Warshel   United States  2013
# 798            NaN             Arieh Warshel          Israel  2013
# 94             NaN             Avram Hershko          Israel  2004
# 830            NaN             Avram Hershko         Hungary  2004
# 228            NaN          Baruj Benacerraf       Venezuela  1980
# 366            NaN          Baruj Benacerraf   United States  1980
# 573            NaN            Betty Williams  United Kingdom  1976
# 805            NaN            Betty Williams         Ireland  1976
# 162            NaN          Brian P. Schmidt   United States  2011
# 1047           NaN          Brian P. Schmidt       Australia  2011
# 498          China            Charles K. Kao   United States  2009
# 831          China            Charles K. Kao       Hong Kong  2009
# 586   South Africa            Sydney Brenner  United Kingdom  2002
# 172            NaN          Thomas C. Südhof   United States  2013
# 905            NaN          Thomas C. Südhof         Germany  2013
# 294            NaN             Tsung-Dao Lee   United States  1957
# 975            NaN             Tsung-Dao Lee           China  1957
# 333            NaN          Wassily Leontief   United States  1973
# 684            NaN          Wassily Leontief          Russia  1973
# 489            NaN            Yoichiro Nambu   United States  2008
# 773            NaN            Yoichiro Nambu           Japan  2008

# %% [markdown]
# 残りの重複については、基準を決めて調査してどのデータを残すのかを決めることもできますが、ここでは簡便のために確率的な方法をとります。
#
# つまり、重複しているデータの中から無作為に半分を選び取り、残りの半分を削除します。

# %% [markdown]
# まず、インデックスをランダムにシャッフルします。

# %%
df = df.reindex(np.random.permutation(df.index))

# %%
df
# Out:
#     born_in                category         country     date_of_birth  \
# 147     NaN                   Peace  United Kingdom  26 December 1872
# 198     NaN  Physiology or Medicine   United States   August 20, 1913
# 364     NaN               Chemistry   United States      May 22, 1912
# 763     NaN              Literature           Japan      14 June 1899
# 223     NaN               Economics   United States       15 May 1915
# ..      ...                     ...             ...               ...
# 326     NaN                 Physics   United States        1908-05-23
# 335     NaN               Chemistry   United States     June 19, 1910
# 212     NaN  Physiology or Medicine   United States    April 10, 1927
# 521     NaN                 Physics  United Kingdom        1842-11-12
# 832     NaN              Literature       Guatemala  October 19, 1899
#
#          date_of_death gender  \
# 147     7 October 1967   male
# 198     April 17, 1994   male
# 364  December 19, 2004   male
# 763      16 April 1972   male
# 223   13 December 2009   male
# ..                 ...    ...
# 326         1991-01-30   male
# 335  September 9, 1985   male
# 212   January 15, 2010   male
# 521         1919-06-30   male
# 832       June 9, 1974   male
#
#                                                   link  \
# 147         http://en.wikipedia.org/wiki/Norman_Angell
# 198  http://en.wikipedia.org/wiki/Roger_Wolcott_Sperry
# 364      http://en.wikipedia.org/wiki/Herbert_C._Brown
# 763     http://en.wikipedia.org/wiki/Yasunari_Kawabata
# 223     http://en.wikipedia.org/wiki/Paul_A._Samuelson
# ..                                                 ...
# 326          http://en.wikipedia.org/wiki/John_Bardeen
# 335         http://en.wikipedia.org/wiki/Paul_J._Flory
# 212  http://en.wikipedia.org/wiki/Marshall_Warren_N...
# 521  http://en.wikipedia.org/wiki/John_William_Stru...
# 832  http://en.wikipedia.org/wiki/Miguel_%C3%81ngel...
#
#                           name                            place_of_birth  \
# 147              Norman Angell                        Holbeach , England
# 198            Roger W. Sperry                     Hartford, Connecticut
# 364           Herbert C. Brown                   London ,  England ,  UK
# 763          Yasunari Kawabata                              Osaka, Japan
# 223          Paul A. Samuelson                        Gary, Indiana, USA
# ..                         ...                                       ...
# 326               John Bardeen                 Madison, Wisconsin , U.S.
# 335              Paul J. Flory                  Sterling, Illinois , USA
# 212  Marshall Warren Nirenberg                             New York City
# 521                John Strutt  Langford Grove,  Maldon, Essex , England
# 832      Miguel Ángel Asturias                 Guatemala City, Guatemala
#
#                               place_of_death  \
# 147                Croydon , Surrey, England
# 198                     Pasadena, California
# 364                Lafayette, Indiana ,  USA
# 763                Kamakura, Kanagawa, Japan
# 223              Belmont, Massachusetts, USA
# ..                                       ...
# 326             Boston, Massachusetts , U.S.
# 335                Big Sur, California , USA
# 212                            New York City
# 521  Terling Place,  Witham, Essex , England
# 832                            Madrid, Spain
#
#                                                   text  year
# 147                        Norman Angell , Peace, 1933  1933
# 198     Roger W. Sperry , Physiology or Medicine, 1981  1981
# 364                 Herbert C. Brown , Chemistry, 1979  1979
# 763               Yasunari Kawabata , Literature, 1968  1968
# 223                Paul A. Samuelson , Economics, 1970  1970
# ..                                                 ...   ...
# 326                       John Bardeen , Physics, 1972  1972
# 335                    Paul J. Flory , Chemistry, 1974  1974
# 212  Marshall Warren Nirenberg , Physiology or Medi...  1968
# 521    John Strutt, 3rd Baron Rayleigh , Physics, 1904  1904
# 832           Miguel Ángel Asturias , Literature, 1967  1967
#
# [935 rows x 12 columns]

# %% [markdown]
# 次に、`drop_duplicates`で重複データのうち、最初に出現したものだけを残します。

# %%
df = df.drop_duplicates(["name", "year"])

# %% [markdown]
# 再度インデックスを順番に並べます。

# %%
df = df.sort_index()

# %%
all_dupes = df[df.duplicated("name", keep=False)]

# %%
all_dupes.sort_values(["name", "year"])[["born_in", "name", "country", "year", "category"]]
# Out:
#     born_in                    name         country  year   category
# 548     NaN        Frederick Sanger  United Kingdom  1958  Chemistry
# 580     NaN        Frederick Sanger  United Kingdom  1980  Chemistry
# 292     NaN            John Bardeen   United States  1956    Physics
# 326     NaN            John Bardeen   United States  1972    Physics
# 285     NaN        Linus C. Pauling   United States  1954  Chemistry
# 309     NaN        Linus C. Pauling   United States  1962      Peace
# 706     NaN  Marie Skłodowska-Curie          Poland  1903    Physics
# 709     NaN  Marie Skłodowska-Curie          France  1911  Chemistry

# %% [markdown]
# 重複が正しく、実際に2回受賞した人のみになりました。

# %%
# 更に欠損値の処理

# %%
len(df)
# Out:
# 896

# %%
df.count()
# Out:
# born_in           133
# category          893
# country           865
# date_of_birth     888
# date_of_death     588
# gender            888
# link              896
# name              896
# place_of_birth    862
# place_of_death    546
# text              896
# year              896
# dtype: int64

# %% [markdown]
# カテゴリがないデータが3つあるようです。
#
# ちなみに、カテゴリの名称はこちら。

# %%
df["category"].value_counts()
# Out:
# category
# Physiology or Medicine    212
# Physics                   206
# Chemistry                 174
# Literature                114
# Peace                     110
# Economics                  77
# Name: count, dtype: int64

# %%
df[df["category"].isnull()]
# Out:
#     born_in category country    date_of_birth     date_of_death gender  \
# 812   India      NaN     NaN  January 9, 1922  November 9, 2011   male
# 815   India      NaN     NaN  3 November 1933               NaN   male
# 922     NaN      NaN  France     28 June 1873   5 November 1944   male
#
#                                                link               name  \
# 812  http://en.wikipedia.org/wiki/Hargobind_Khorana  Hargobind Khorana
# 815        http://en.wikipedia.org/wiki/Amartya_Sen        Amartya Sen
# 922      http://en.wikipedia.org/wiki/Alexis_Carrel      Alexis Carrel
#
#                              place_of_birth                 place_of_death  \
# 812             Raipur ,  Punjab , Pakistan  Concord, Massachusetts , U.S.
# 815                     Dhaka ,  Bangladesh                            NaN
# 922  Sainte-Foy-lès-Lyon ,  Rhône ,  France                            NaN
#
#                                                   text  year
# 812  Hargobind Khorana *,  born in  Kabirwala , Bri...  1968
# 815             Amartya Sen *, Economic Sciences, 1998  1998
# 922                     Alexis Carrel , Medicine, 1912  1912

# %% [markdown]
# 手動で補完します。

# %%
df.loc[812, "category"] = "Physiology or Medicine"

# %%
df.loc[815, "category"] = "Economics"

# %%
df.loc[922, "category"] = "Physiology or Medicine"

# %%
df.count()
# Out:
# born_in           133
# category          896
# country           865
# date_of_birth     888
# date_of_death     588
# gender            888
# link              896
# name              896
# place_of_birth    862
# place_of_death    546
# text              896
# year              896
# dtype: int64

# %% [markdown]
# 更に、ジェンダーも数人欠けています。

# %%
df[df["gender"].isnull()]["name"]
# Out:
# 3                         Institut de Droit International
# 156                               Friends Service Council
# 267     American Friends Service Committee  (The Quakers)
# 574                                 Amnesty International
# 632                              Médecins Sans Frontières
# 650                                         Ragnar Granit
# 1000     Pugwash Conferences on Science and World Affairs
# 1033                   International Atomic Energy Agency
# Name: name, dtype: object

# %% [markdown]
# これを見ると、Ragnar Granit以外は団体です。今回は個人に着目したいので、団体の受賞者は削除することにします。

# %%
df.loc[650, "gender"] = "male"

# %%
df = df[df["gender"].notnull()]

# %%
df.count()
# Out:
# born_in           133
# category          889
# country           858
# date_of_birth     888
# date_of_death     588
# gender            889
# link              889
# name              889
# place_of_birth    862
# place_of_death    546
# text              889
# year              889
# dtype: int64

# %% [markdown]
# 欠けているデータをできる限り補完してみます。

# %%
df[df["date_of_birth"].isnull()]["name"]
# Out:
# 782    Hiroshi Amano
# Name: name, dtype: object

# %%
df.loc[782, "date_of_birth"] = "11 September 1960"

# %%
df[df["country"].isnull()]
# Out:
#                      born_in                category country  \
# 1     Bosnia and Herzegovina              Literature     NaN
# 29            Czech Republic  Physiology or Medicine     NaN
# 53                   Germany  Physiology or Medicine     NaN
# 88                     Italy  Physiology or Medicine     NaN
# 101                   Mexico               Chemistry     NaN
# 268            United States              Literature     NaN
# 340            United States                 Physics     NaN
# 530           United Kingdom  Physiology or Medicine     NaN
# 589           United Kingdom               Economics     NaN
# 606      Trinidad and Tobago              Literature     NaN
# 657                   Sweden  Physiology or Medicine     NaN
# 668              Saint Lucia               Economics     NaN
# 690                   Russia              Literature     NaN
# 708                   Poland                 Physics     NaN
# 722                     Peru              Literature     NaN
# 754              Netherlands  Physiology or Medicine     NaN
# 800                  Ireland              Literature     NaN
# 806                  Ireland              Literature     NaN
# 812                    India  Physiology or Medicine     NaN
# 815                    India               Economics     NaN
# 819                  Hungary                 Physics     NaN
# 824                  Hungary  Physiology or Medicine     NaN
# 826                  Hungary                 Physics     NaN
# 828                  Hungary               Chemistry     NaN
# 867                  Germany              Literature     NaN
# 872                  Germany  Physiology or Medicine     NaN
# 884                  Germany                 Physics     NaN
# 1023                 Austria  Physiology or Medicine     NaN
# 1027                 Austria  Physiology or Medicine     NaN
# 1041               Australia               Chemistry     NaN
# 1046               Australia  Physiology or Medicine     NaN
#
#           date_of_birth      date_of_death  gender  \
# 1        9 October 1892      13 March 1975    male
# 29     December 5, 1896   October 20, 1984    male
# 53       April 17, 1946      March 1, 1995    male
# 88       6 October 1937                NaN    male
# 101          1943-03-19                NaN    male
# 268   26 September 1888     4 January 1965    male
# 340        July 9, 1926                NaN    male
# 530    6 September 1876      16 March 1935    male
# 589    4 September 1934        27 May 2009    male
# 606      17 August 1932                NaN    male
# 657          1924-06-03                NaN    male
# 668    January 23, 1915      June 15, 1991    male
# 690         24 May 1940    28 January 1996    male
# 708   December 29, 1852        May 9, 1931    male
# 722      March 28, 1936                NaN    male
# 754       15 April 1907   21 December 1988    male
# 800        26 July 1856    2 November 1950    male
# 806       13 April 1939     30 August 2013    male
# 812     January 9, 1922   November 9, 2011    male
# 815     3 November 1933                NaN    male
# 819        June 7, 1862       May 20, 1947    male
# 824         3 June 1899       13 June 1972    male
# 826         5 June 1900    8 February 1979    male
# 828          1927-05-22                NaN    male
# 867          1877-07-02         1962-08-09    male
# 872       June 12, 1899      July 24, 1986    male
# 884        July 2, 1906      March 6, 2005    male
# 1023       June 3, 1873  December 25, 1961    male
# 1027         1886-11-20         1982-06-12    male
# 1041   7 September 1917    8 December 2013    male
# 1046         1948-11-26                NaN  female
#
#                                                    link  \
# 1               http://en.wikipedia.org/wiki/Ivo_Andric
# 29     http://en.wikipedia.org/wiki/Carl_Ferdinand_Cori
# 53    http://en.wikipedia.org/wiki/Georges_J.F._K%C3...
# 88          http://en.wikipedia.org/wiki/Mario_Capecchi
# 101        http://en.wikipedia.org/wiki/Mario_J._Molina
# 268            http://en.wikipedia.org/wiki/T._S._Eliot
# 340       http://en.wikipedia.org/wiki/Ben_R._Mottelson
# 530   http://en.wikipedia.org/wiki/John_James_Rickar...
# 589    http://en.wikipedia.org/wiki/Clive_W._J._Granger
# 606          http://en.wikipedia.org/wiki/V._S._Naipaul
# 657         http://en.wikipedia.org/wiki/Torsten_Wiesel
# 668   http://en.wikipedia.org/wiki/Arthur_Lewis_(eco...
# 690   http://en.wikipedia.org/wiki/Iosif_Aleksandrov...
# 708   http://en.wikipedia.org/wiki/Albert_Abraham_Mi...
# 722     http://en.wikipedia.org/wiki/Mario_Vargas_Llosa
# 754     http://en.wikipedia.org/wiki/Nikolaas_Tinbergen
# 800    http://en.wikipedia.org/wiki/George_Bernard_Shaw
# 806          http://en.wikipedia.org/wiki/Seamus_Heaney
# 812      http://en.wikipedia.org/wiki/Hargobind_Khorana
# 815            http://en.wikipedia.org/wiki/Amartya_Sen
# 819         http://en.wikipedia.org/wiki/Philipp_Lenard
# 824   http://en.wikipedia.org/wiki/Georg_von_B%C3%A9...
# 826           http://en.wikipedia.org/wiki/Dennis_Gabor
# 828     http://en.wikipedia.org/wiki/George_Andrew_Olah
# 867           http://en.wikipedia.org/wiki/Herman_Hesse
belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 29                             Cambridge, Massachusetts
# 53                                 Freiburg im Breisgau
# 88                                                  NaN
# 101                                                 NaN
# 268                          London, UK, United Kingdom
# 340                                                 NaN
# 530                                Aberdeen ,  Scotland
# 589                San Diego, California, United States
# 606                                                 NaN
# 657                                                 NaN
# 668                                            Barbados
# 690                      New York City, New York ,  USA
# 708                                Pasadena, California
# 722                                                 NaN
# 754                                Oxford , England, UK
# 800                                    Ayot St Lawrence
# 806                                   Dublin ,  Ireland
# 812                       Concord, Massachusetts , U.S.
# 815                                                 NaN
# 819                             Messelhausen ,  Germany
# 824                 Honolulu ,  Hawaii ,  United States
# 826                              London, United Kingdom
# 828                                                 NaN
# 867                            Montagnola , Switzerland
# 872                       Poughkeepsie, New York , U.S.
# 884                                 Ithaca ,  NY , U.S.
# 1023                     New York City ,  United States
# 1027                                  Munich ,  Germany
# 1041                                            England
# 1046                                                NaN
#
#                                                    text  year
# 1     Ivo Andric *,  born in then  Austria–Hungary ,...  1961
# 29    Carl Ferdinand Cori *,  born in then Austria-H...  1947
# 53    Georges J.F. Köhler *, Physiology or Medicine,...  1984
# 88       Mario Capecchi *, Physiology or Medicine, 2007  2007
# 101      Mario José Molina Henríquez *, Chemistry, 1995  1995
# 268                     T. S. Eliot *, Literature, 1948  1948
# 340                   Ben R. Mottelson *, Physics, 1975  1975
# 530   John James Rickard Macleod *, Physiology or Me...  1923
# 589              Clive W. J. Granger *, Economics, 2003  2003
# 606                   V. S. Naipaul *, Literature, 2001  2001
# 657      Torsten Wiesel *, Physiology or Medicine, 1981  1981
# 668                 Sir Arthur Lewis *, Economics, 1979  1979
# 690    Iosif Aleksandrovich Brodsky *, Literature, 1987  1987
# 708   Albert Abraham Michelson *  born in partitione...  1907
# 722              Mario Vargas Llosa *, Literature, 2010  2010
# 754   Nikolaas Tinbergen *, Physiology or Medicine, ...  1973
# 800             George Bernard Shaw *, Literature, 1925  1925
# 806                   Seamus Heaney *, Literature, 1995  1995
# 812   Hargobind Khorana *,  born in  Kabirwala , Bri...  1968
# 815              Amartya Sen *, Economic Sciences, 1998  1998
# 819   Philipp Lenard  (Lénárd Fülöp)*,  born in then...  1905
# 824   Georg von Békésy * (Békésy György), Physiology...  1961
# 826         Dennis Gabor * (Gábor Dénes), Physics, 1971  1971
# 828   George Andrew Olah * (Oláh György), Chemistry,...  1994
# 867                    Herman Hesse *, Literature, 1946  1946
# 872   Fritz Albert Lipmann *, Physiology or Medicine...  1953
# 884                Hans Albrecht Bethe *, Physics, 1967  1967
# 1023         Otto Loewi *, Physiology or Medicine, 1936  1936
# 1027    Karl von Frisch *, Physiology or Medicine, 1973  1973
# 1041           John Warcup Cornforth *, Chemistry, 1975  1975
# 1046  Elizabeth H. Blackburn *, Physiology or Medici...  2009

# %% [markdown]
# `country`は欠損値が多いので個別に埋めることはせず、`born_in`を持ってくることにします。

# %%
df.loc[df["country"].isnull(), "country"] = df[df["country"].isnull()]["born_in"]

# %%
df.count()
# Out:
# born_in           133
# category          889
# country           889
# date_of_birth     889
# date_of_death     588
# gender            889
# link              889
# name              889
# place_of_birth    862
# place_of_death    546
# text              889
# year              889
# dtype: int64

# %% [markdown]
# これで、`category`、`date_of_birth`、`gender`、`country`、`year`、`text`等主要なデータが揃っているクリーンなデータができました。

# %% [markdown]
# また、tidy dataにもなっています。

# %% [markdown]
# 最後に日付のフォーマットを整えます。

# %%
# 日付

# %%
df["date_of_birth"] = pd.to_datetime(df["date_of_birth"], format="mixed", errors="raise")

# %%
pd.to_datetime(df["date_of_death"], format="mixed", errors="raise")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:684, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 pd.to_datetime(df["date_of_death"], format="mixed", errors="raise")
#
# File ~/infovis/virtualenvs/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/infovis/virtualenvs/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     432 if format is not None and format != "mixed":
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#     438     yearfirst=yearfirst,
#     439     utc=utc,
#     440     errors=errors,
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#     447     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/infovis/virtualenvs/.venv/lib/python3.12/site-packages/pandas/core/arrays/datetimes.py:2398, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2395 # if str-dtype, convert
#    2396 data = np.asarray(data, dtype=np.object_)
# -> 2398 result, tz_parsed = tslib.array_to_datetime(
#    2399     data,
#    2400     errors=errors,
#    2401     utc=utc,
#    2402     dayfirst=dayfirst,
#    2403     yearfirst=yearfirst,
#    2404     creso=abbrev_to_npy_unit(out_unit),
#    2405 )
#    2407 if tz_parsed is not None:
#    2408     # We can take a shortcut since the datetime64 numpy array
#    2409     #  is in UTC
#    2410     return result, tz_parsed
#
# File tslib.pyx:414, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:553, in pandas._libs.tslib.array_to_datetime()
#
# File conversion.pyx:641, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File parsing.pyx:336, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File parsing.pyx:688, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: month must be in 1..12: 1968-23-07, at position 118

# %% [markdown]
# 生年月日は無事に変換できましたが、没年月日ではエラーが出ました。
#
# エラーを捕捉して修正します。

# %%
for i, row in df.iterrows():
    try:
        pd.to_datetime(row["date_of_death"], format="mixed", errors="raise")
    except:
        print(f"{row.date_of_death.ljust(30)} ({row['name']}, {i})")
# Out:
# 1968-23-07                     (Henry Hallett Dale, 150)
# May 30, 2011 (aged 89)         (Rosalyn Yalow, 349)
# living                         (David Trimble, 581)
# Diederik Korteweg              (Johannes Diderik van der Waals, 746)
# living                         (Shirin Ebadi, 809)
# living                         (Rigoberta Menchú, 833)
# 1 February 1976, age 74        (Werner Karl Heisenberg, 858)

# %% [markdown]
# エラーが発生している箇所で、日付の様々なフォーマットが確認できます。

# %% [markdown]
# 手動で修正することもできますが、ここでは一律で欠損値に変換したいと思います。

# %%
df["date_of_death"] = pd.to_datetime(df["date_of_death"], errors="coerce")

# %% [markdown]
# 日付をきちんと変換できたので、ノーベル賞受賞時の受賞者の年齢を計算してみます。

# %%
df["award_age"] = df.year - pd.DatetimeIndex(df["date_of_birth"]).year

# %% [markdown]
# 気になるので、最年少と最高齢受賞者を見てみましょう。

# %%
df.sort_values("award_age")[["name", "award_age", "year", "category"]]
# Out:
#                        name  award_age  year                category
# 725        Malala Yousafzai         17  2014                   Peace
# 525  William Lawrence Bragg         25  1915                 Physics
# 626    Georges J. F. Köhler         30  1976  Physiology or Medicine
# 146              Paul Dirac         31  1933                 Physics
# 858  Werner Karl Heisenberg         31  1932                 Physics
# ..                      ...        ...   ...                     ...
# 773          Yoichiro Nambu         87  2008                 Physics
# 453       Raymond Davis Jr.         88  2002                 Physics
# 593           Doris Lessing         88  2007              Literature
# 169        Lloyd S. Shapley         89  2012               Economics
# 488          Leonid Hurwicz         90  2007               Economics
#
# [889 rows x 4 columns]

# %% [markdown]
# 最年少はマララさんですね。比較的最近です。
#
# その次は比較的早い時代の、ローレンス・ブラッグ。受賞理由は「X線による結晶構造解析に関する研究」、現代結晶学の創始者だそうです。
#
# 最高齢は経済学者のレオニード・ハーヴィッツ。「メカニズムデザインの理論の基礎を確立した功績を称えて」とのこと。

# %% [markdown]
# ともかくこれで、分析しやすいキレイなデータができました。
#
# ファイルに保存しておきます。元のデータがローカルにある時は、フォルダを分けて保存すると良いでしょう。

# %%
df.to_csv("./data/nobel_prize_data_cleaned.tsv", index=False, header=True, sep="\t")

# %%
df
# Out:
#                     born_in                category                 country  \
# 0                       NaN  Physiology or Medicine               Argentina
# 1    Bosnia and Herzegovina              Literature  Bosnia and Herzegovina
# 2                       NaN                   Peace                 Belgium
# 3                       NaN              Literature                 Belgium
# 4                       NaN                   Peace                 Belgium
# ..                      ...                     ...                     ...
# 884                     NaN                 Physics               Australia
# 885                     NaN                   Peace               Argentina
# 886                     NaN  Physiology or Medicine               Argentina
# 887                  France               Chemistry               Argentina
# 888                     NaN                   Peace               Argentina
#
#     date_of_birth date_of_death gender  \
# 0      1927-10-08    2002-03-24   male
# 1      1892-10-09    1975-03-13   male
# 2      1829-07-26    1912-10-06   male
# 3      1862-08-29    1949-05-06   male
# 4      1854-04-22    1943-05-14   male
# ..            ...           ...    ...
# 884    1967-02-24           NaN   male
# 885    1878-11-01           NaN   male
# 886    1887-04-10           NaN   male
# 887    1906-09-06           NaN   male
# 888    1931-11-26           NaN   male
#
#                                                   link                   name  \
# 0     http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein         César Milstein
# 1              http://en.wikipedia.org/wiki/Ivo_Andric             Ivo Andric
# 2    http://en.wikipedia.org/wiki/Auguste_Marie_Fra...      Auguste Beernaert
# 3     http://en.wikipedia.org/wiki/Maurice_Maeterlinck    Maurice Maeterlinck
# 4       http://en.wikipedia.org/wiki/Henri_La_Fontaine      Henri La Fontaine
# ..                                                 ...                    ...
# 884      http://en.wikipedia.org/wiki/Brian_P._Schmidt       Brian P. Schmidt
# 885  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...  Carlos Saavedra Lamas
# 886      http://en.wikipedia.org/wiki/Bernardo_Houssay       Bernardo Houssay
# 887  http://en.wikipedia.org/wiki/Luis_Federico_Leloir   Luis Federico Leloir
# 888  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...  Adolfo Pérez Esquivel
#
#                                         place_of_birth  \
# 0                            Bahía Blanca ,  Argentina
# 1    Dolac (village near Travnik), Austria-Hungary ...
# 2               Ostend ,  Netherlands  (now  Belgium )
# 3                                     Ghent ,  Belgium
# 4                                             Brussels
# ..                                                 ...
# 884                                  Missoula, Montana
# 885                          Buenos Aires ,  Argentina
# 886                          Buenos Aires ,  Argentina
# 887                                    Paris ,  France
# 888                                       Buenos Aires
#
#                                         place_of_death  \
# 0                                  Cambridge , England
# 1    Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                               Lucerne ,  Switzerland
# 3                                       Nice ,  France
# 4                                              Belgium
# ..                                                 ...
# 884                                                NaN
# 885                            Buenos Aires, Argentina
# 886                          Buenos Aires ,  Argentina
# 887                          Buenos Aires ,  Argentina
# 888                                                NaN
#
#                                                   text  year  award_age
# 0        César Milstein , Physiology or Medicine, 1984  1984         57
# 1    Ivo Andric *,  born in then  Austria–Hungary ,...  1961         69
# 2                      Auguste Beernaert , Peace, 1909  1909         80
# 3               Maurice Maeterlinck , Literature, 1911  1911         49
# 4                      Henri La Fontaine , Peace, 1913  1913         59
# ..                                                 ...   ...        ...
# 884  Brian P. Schmidt ,  born in the United States ...  2011         44
# 885                Carlos Saavedra Lamas , Peace, 1936  1936         58
# 886    Bernardo Houssay , Physiology or Medicine, 1947  1947         60
# 887             Luis Federico Leloir , Chemistry, 1970  1970         64
# 888                Adolfo Pérez Esquivel , Peace, 1980  1980         49
#
# [889 rows x 13 columns]

# %%
# 最終的なデータ仕様書

# %% [markdown]
# | カラム | カラムの説明 | データ型 | 尺度 | 値の説明 | NULL | UNIQ | CHECK |
# | :-- | :-- | :-- | :-- | :-- | --- | --- | --- |
# | born_in | 出生地 | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | category | 賞の種類 | カテゴリ | 名義尺度 |  |  |  |  |
# | country | 国籍 | カテゴリ | 名義尺度 |  |  |  |  |
# | date_of_birth | 生年月日 | 数値 | 間隔尺度 |  |  |  |  |
# | date_of_death | 没年月日 | 数値 | 間隔尺度 |  | ✔ |  |  |
# | gender | 性別 | カテゴリ | 名義尺度 |  |  |  |  |
# | link | ウィキペディアへのリンク | テキスト | テキスト |  |  |  |  |
# | name | 氏名 | テキスト | テキスト |  |  |  |  |
# | place_of_birth | 出生地 | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | place_of_death | 死没地 | カテゴリ | 名義尺度 |  | ✔ |  |  |
# | text | 説明 | テキスト | テキスト |  |  |  |  |
# | year | 受賞年 | 数値 | 間隔尺度 |  |  |  | 1901 $\leq$ x $\leq$ 2014 |
# | award_age | 受賞年齢 | 数値 | 比例尺度 |  |  |  |  |
#
#
# * `NULL`: 欠損値が存在するか
# * `UNIQ`: 重複しない値か
# * `CHECK`: 満たすべき条件

# %% [markdown]
# ## データの探索（探索的可視化）
#
# データの前処理の中でもある程度データを探索してきました。
#
# 続けて、いくつかの気になった点について探索的可視化を行い、最初に立てた「問い」に基づいてどのような仮説が設定できそうかを探っていきます。

# %% [markdown]
# 以下の例ではMatplotlibとそのラッパーのseaborn、また部分的にPlotlyという可視化ライブラリを使います。
#
# Altairでこれらの図をどのように再現できるか、ぜひ試してみてください。

# %%
# !pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (163 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 23.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0 pyparsing-3.2.0 seaborn-0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# seabornのスタイルを使う

sns.set()

# %% [markdown]
# ### 男女間の差

# %% [markdown]
# 実はpandasはplotメソッドでmatplotlibを呼び出すことができるため、自分で見るための図は簡単に作れます。

# %%
by_gender = df.groupby("gender")
by_gender.size().plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
by_gender.size()
# Out:
# gender
# female     48
# male      841
# dtype: int64

# %%
by_cat_gen = df.groupby(["category", "gender"])

# %%
by_cat_gen.size()
# Out:
# category                gender
# Chemistry               female      4
#                         male      170
# Economics               female      1
#                         male       77
# Literature              female     13
#                         male      101
# Peace                   female     16
#                         male       87
# Physics                 female      2
#                         male      204
# Physiology or Medicine  female     12
#                         male      202
# dtype: int64

# %%
by_cat_gen.size().plot(kind="barh")
# Out:
# <Axes: ylabel='category,gender'>

# %% [markdown]
# データを横持ちにして再度プロットしてみます。

# %%
by_cat_gen.size().unstack()
# Out:
# gender                  female  male
# category
# Chemistry                    4   170
# Economics                    1    77
# Literature                  13   101
# Peace                       16    87
# Physics                      2   204
# Physiology or Medicine      12   202

# %%
by_cat_gen.size().unstack().plot(kind="barh")
# Out:
# <Axes: ylabel='category'>

# %% [markdown]
# 受賞者の合計を計算し、女性受賞者の人数順に並べ替えます。

# %%
cat_gen_sz = by_cat_gen.size().unstack()
cat_gen_sz["total"] = cat_gen_sz.sum(axis=1)
cat_gen_sz = cat_gen_sz.sort_values(by="female", ascending=True)
cat_gen_sz[["female", "total", "male"]].plot(kind="barh")
# Out:
# <Axes: ylabel='category'>

# %%
df[(df.category == 'Physics') & (df.gender == 'female')][['name', 'country','year']]
# Out:
#                        name        country  year
# 312    Maria Goeppert-Mayer  United States  1963
# 706  Marie Skłodowska-Curie         Poland  1903

# %% [markdown]
# [マリア・ゲッパート＝メイヤー](https://ja.wikipedia.org/wiki/%E3%83%9E%E3%83%AA%E3%82%A2%E3%83%BB%E3%82%B2%E3%83%83%E3%83%91%E3%83%BC%E3%83%88%EF%BC%9D%E3%83%A1%E3%82%A4%E3%83%A4%E3%83%BC)
#
# 「原子核の殻構造に関する研究」

# %% [markdown]
# インタラクティブな図を作ると、細かい数値が見やすい。

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from plotly) (24.1)
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.1 tenacity-9.0.0

# %%
import plotly.express as px
from plotly import offline

# %%
count_df = cat_gen_sz.stack().reset_index()

# %%
count_df = count_df.rename(columns={0: "count"})

# %%
count_df
# Out:
#                   category  gender  count
# 0                Economics  female      1
# 1                Economics    male     77
# 2                Economics   total     78
# 3                  Physics  female      2
# 4                  Physics    male    204
# 5                  Physics   total    206
# 6                Chemistry  female      4
# 7                Chemistry    male    170
# 8                Chemistry   total    174
# 9   Physiology or Medicine  female     12
# 10  Physiology or Medicine    male    202
# 11  Physiology or Medicine   total    214
# 12              Literature  female     13
# 13              Literature    male    101
# 14              Literature   total    114
# 15                   Peace  female     16
# 16                   Peace    male     87
# 17                   Peace   total    103

# %% [markdown]
# Tidy dataにしてから使う。

# %%
# !pip install nbformat>=5.1
# !pip show nbformat
# Out:
# Name: nbformat
# Version: 4.2.0
# Summary: The Jupyter Notebook format
# Home-page: http://jupyter.org
# Author: Jupyter Development Team
# Author-email: jupyter@googlegroups.com
# License: BSD
# Location: /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages
# Requires: ipython-genutils, jsonschema, jupyter-core, traitlets
# Required-by: jupyter_server, nbclient, nbconvert

# %%
# !pip install jupyter ipython
# Out:
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipython in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (8.29.0)
# Collecting notebook (from jupyter)
#   Using cached notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyter) (8.1.5)
# Collecting jupyterlab (from jupyter)
#   Downloading jupyterlab-4.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: decorator in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack-data in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: comm>=0.1.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.8)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.13)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jinja2>=3.0.3 (from jupyterlab->jupyter)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting setuptools>=40.1.0 (from jupyterlab->jupyter)
#   Downloading setuptools-75.4.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: beautifulsoup4 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (4.12.3)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter)
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markupsafe>=2.0 (from nbconvert->jupyter)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: nbformat>=5.7 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter)
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyterlab (from jupyter)
#   Using cached jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from stack-data->ipython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from stack-data->ipython) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter)
#   Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter)
#   Using cached httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached prometheus_client-0.21.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter)
#   Downloading json5-0.9.28-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.21.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached notebook-7.2.2-py3-none-any.whl (5.0 MB)
# Using cached jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.6-py3-none-any.whl (78 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading setuptools-75.4.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Downloading json5-0.9.28-py3-none-any.whl (30 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.21.0-py3-none-any.whl (54 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, setuptools, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, mistune, markupsafe, jupyterlab-pygments, jsonpointer, json5, httpcore, fqdn, defusedxml, bleach, babel, async-lru, anyio, jupyter-server-terminals, jinja2, httpx, cffi, arrow, isoduration, argon2-cffi-bindings, argon2-cffi, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed anyio-4.6.2.post1 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.16.0 bleach-6.2.0 cffi-1.17.1 defusedxml-0.7.1 fqdn-1.5.1 httpcore-1.0.6 httpx-0.27.2 isoduration-20.11.0 jinja2-3.1.4 json5-0.9.28 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 markupsafe-3.0.2 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 notebook-7.2.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.0 pycparser-2.22 python-json-logger-2.0.7 pyyaml-6.0.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 setuptools-75.4.0 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20241003 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1

# %%
fig = px.bar(count_df, x="count", y="category", color="gender", barmode="group")
offline.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 2
#       1 fig = px.bar(count_df, x="count", y="category", color="gender", barmode="group")
# ----> 2 offline.iplot(fig)
#
# File ~/infovis/virtualenvs/.venv/lib/python3.12/site-packages/plotly/offline/offline.py:387, in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     382 post_script = build_save_image_post_script(
#     383     image, filename, image_height, image_width, "iplot"
#     384 )
#     386 # Show figure
# --> 387 pio.show(
#     388     figure,
#     389     validate=validate,
#     390     config=config,
#     391     auto_play=auto_play,
#     392     post_script=post_script,
#     393     animation_opts=animation_opts,
#     394 )
#
# File ~/infovis/virtualenvs/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ### 歴史的傾向

# %% [markdown]
# 例えば、女性の受賞者は時間の推移によって増加しているのでしょうか？時系列にプロットすることで見えてきそうです。

# %%
by_year_gender = df.groupby(["year", "gender"])
year_gen_sz = by_year_gender.size().unstack()
year_gen_sz.plot(kind="bar", figsize=(16, 4))
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# だいぶ見づらいので、x軸のラベルを調整します。

# %%
def thin_xticks(ax, tick_gap=10, rotation=45):
    ticks = ax.xaxis.get_ticklocs()
    ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
    ax.xaxis.set_ticks(ticks[::tick_gap])
    ax.xaxis.set_ticklabels(ticklabels[::tick_gap], rotation=rotation)

    ax.figure.show()

# %% [markdown]
# また、欠損している受賞年（1939–1945年の第二次世界大戦中はノーベル賞が授与されませんでした）は飛ばすのではなく、欠損として表示したいと思います。
#
# indexを振り直します。

# %%
new_index = pd.Index(np.arange(1901, 2015), name="year")
by_year_gender = df.groupby(["year", "gender"])
year_gen_sz = by_year_gender.size().unstack().reindex(new_index)

# %%
year_gen_sz
# Out:
# gender  female  male
# year
# 1901       NaN   6.0
# 1902       NaN   7.0
# 1903       1.0   6.0
# 1904       NaN   5.0
# 1905       1.0   5.0
# 1906       NaN   6.0
# 1907       NaN   7.0
# 1908       NaN   7.0
# 1909       1.0   6.0
# 1910       NaN   4.0
# 1911       1.0   5.0
# 1912       NaN   6.0
# 1913       NaN   5.0
# 1914       NaN   3.0
# 1915       NaN   4.0
# 1916       NaN   1.0
# 1917       NaN   3.0
# 1918       NaN   2.0
# 1919       NaN   4.0
# 1920       NaN   5.0
# 1921       NaN   5.0
# 1922       NaN   5.0
# 1923       NaN   5.0
# 1924       NaN   3.0
# 1925       NaN   6.0
# 1926       1.0   5.0
# 1927       NaN   7.0
# 1928       1.0   3.0
# 1929       NaN   7.0
# 1930       NaN   5.0
# 1931       1.0   5.0
# 1932       NaN   5.0
# 1933       NaN   5.0
# 1934       NaN   6.0
# 1935       1.0   4.0
# 1936       NaN   7.0
# 1937       NaN   7.0
# 1938       1.0   3.0
# 1939       NaN   4.0
# 1940       NaN   NaN
# 1941       NaN   NaN
# 1942       NaN   NaN
# 1943       NaN   4.0
# 1944       NaN   5.0
# 1945       1.0   5.0
# 1946       1.0   8.0
# 1947       1.0   6.0
# 1948       NaN   4.0
# 1949       NaN   6.0
# 1950       NaN   8.0
# 1951       NaN   7.0
# 1952       NaN   7.0
# 1953       NaN   7.0
# 1954       NaN   7.0
# 1955       NaN   4.0
# 1956       NaN  10.0
# 1957       NaN   6.0
# 1958       NaN   9.0
# 1959       NaN   8.0
# 1960       NaN   6.0
# 1961       NaN   8.0
# 1962       NaN  10.0
# 1963       1.0   8.0
# 1964       1.0   7.0
# 1965       NaN   8.0
# 1966       1.0   5.0
# 1967       NaN   9.0
# 1968       NaN   8.0
# 1969       NaN   9.0
# 1970       NaN   9.0
# 1971       NaN   7.0
# 1972       NaN  11.0
# 1973       NaN  13.0
# 1974       NaN  12.0
# 1975       NaN  15.0
# 1976       2.0   8.0
# 1977       1.0   9.0
# 1978       NaN  11.0
# 1979       1.0  11.0
# 1980       NaN  11.0
# 1981       NaN  10.0
# 1982       1.0   8.0
# 1983       1.0   6.0
# 1984       NaN   9.0
# 1985       NaN   7.0
# 1986       1.0  11.0
# 1987       NaN  10.0
# 1988       1.0  10.0
# 1989       NaN  10.0
# 1990       NaN  11.0
# 1991       2.0   5.0
# 1992       1.0   6.0
# 1993       1.0  10.0
# 1994       NaN  14.0
# 1995       1.0  11.0
# 1996       1.0  12.0
# 1997       1.0  10.0
# 1998       NaN  12.0
# 1999       NaN   7.0
# 2000       NaN  13.0
# 2001       NaN  15.0
# 2002       NaN  13.0
# 2003       1.0  10.0
# 2004       3.0   9.0
# 2005       NaN  12.0
# 2006       NaN   8.0
# 2007       1.0  11.0
# 2008       1.0  11.0
# 2009       6.0   8.0
# 2010       NaN  11.0
# 2011       3.0  10.0
# 2012       NaN   9.0
# 2013       1.0  11.0
# 2014       2.0  11.0

# %% [markdown]
# 更に、見やすくするために図を上下に並べて表示することにします。これにはMatplotlibのサブプロットという機能を使います。

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)

ax_f = axes[0]
ax_m = axes[1]

fig.suptitle("Nobel Prize laureates by gender", fontsize=16)

ax_f.bar(year_gen_sz.index, year_gen_sz.female)
ax_f.set_ylabel("Female laureates")

ax_m.bar(year_gen_sz.index, year_gen_sz.male)
ax_m.set_ylabel("Male laureates")

ax_m.set_xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# 女性の受賞者が近年増えているような気もしますが、受賞者全体が増加傾向にあるようにも見えます。共同受賞する人数が増えているためでしょうか？
#
# これについては、例えば「知識量が爆発的に増え、研究者間・分野間の協力が必須となった現代ではノーベル賞の同時受賞人数が増えている」などと仮説を設定していろいろと探索できそうです。

# %% [markdown]
# 更に、このデータに関しては、
#
# * 国別の傾向
#     * 人口1人当たりの受賞者数
#     * 分野別の受賞数
#     * 受賞分布の歴史的傾向
# * 受賞者の年齢と没年齢
# * 受賞者の移住
#
# など、様々な側面で探索できそうです。
#
# 興味があったら問いを立てて、探索してみてください。

# %% [markdown]
# ---
#
# 【演習】上で作成した可視化から2つ選び、Altairで再現してみましょう。
#
# 参考：[Altairの練習](../exercise_5/intro-to-altair.ipynb)、[Altairを使ったデータのエンコーディング](../exercise_5/encoding-with-altair.ipynb)

# %%
# !pip install altair
# !pip install vega_datasets
import pandas as pd
import altair as alt
# Out:
# Requirement already satisfied: altair in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (5.4.1)
# Requirement already satisfied: jinja2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from altair) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from altair) (1.13.5)
# Requirement already satisfied: packaging in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from altair) (24.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from altair) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from jinja2->altair) (3.0.2)
# Requirement already satisfied: vega_datasets in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: pandas in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from vega_datasets) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas->vega_datasets) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas->vega_datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from pandas->vega_datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/mayu/infovis/virtualenvs/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.16.0)

# %%
#your code goes here
df = pd.read_csv("./data/nobel_prize_data_cleaned.tsv", sep="\t")
df
# Out:
#                     born_in                category                 country  \
# 0                       NaN  Physiology or Medicine               Argentina
# 1    Bosnia and Herzegovina              Literature  Bosnia and Herzegovina
# 2                       NaN                   Peace                 Belgium
# 3                       NaN              Literature                 Belgium
# 4                       NaN                   Peace                 Belgium
# ..                      ...                     ...                     ...
# 884                     NaN                 Physics               Australia
# 885                     NaN                   Peace               Argentina
# 886                     NaN  Physiology or Medicine               Argentina
# 887                  France               Chemistry               Argentina
# 888                     NaN                   Peace               Argentina
#
#     date_of_birth date_of_death gender  \
# 0      1927-10-08    2002-03-24   male
# 1      1892-10-09    1975-03-13   male
# 2      1829-07-26    1912-10-06   male
# 3      1862-08-29    1949-05-06   male
# 4      1854-04-22    1943-05-14   male
# ..            ...           ...    ...
# 884    1967-02-24           NaN   male
# 885    1878-11-01           NaN   male
# 886    1887-04-10           NaN   male
# 887    1906-09-06           NaN   male
# 888    1931-11-26           NaN   male
#
#                                                   link                   name  \
# 0     http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein         César Milstein
# 1              http://en.wikipedia.org/wiki/Ivo_Andric             Ivo Andric
# 2    http://en.wikipedia.org/wiki/Auguste_Marie_Fra...      Auguste Beernaert
# 3     http://en.wikipedia.org/wiki/Maurice_Maeterlinck    Maurice Maeterlinck
# 4       http://en.wikipedia.org/wiki/Henri_La_Fontaine      Henri La Fontaine
# ..                                                 ...                    ...
# 884      http://en.wikipedia.org/wiki/Brian_P._Schmidt       Brian P. Schmidt
# 885  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...  Carlos Saavedra Lamas
# 886      http://en.wikipedia.org/wiki/Bernardo_Houssay       Bernardo Houssay
# 887  http://en.wikipedia.org/wiki/Luis_Federico_Leloir   Luis Federico Leloir
# 888  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...  Adolfo Pérez Esquivel
#
#                                         place_of_birth  \
# 0                            Bahía Blanca ,  Argentina
# 1    Dolac (village near Travnik), Austria-Hungary ...
# 2               Ostend ,  Netherlands  (now  Belgium )
# 3                                     Ghent ,  Belgium
# 4                                             Brussels
# ..                                                 ...
# 884                                  Missoula, Montana
# 885                          Buenos Aires ,  Argentina
# 886                          Buenos Aires ,  Argentina
# 887                                    Paris ,  France
# 888                                       Buenos Aires
#
#                                         place_of_death  \
# 0                                  Cambridge , England
# 1    Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                               Lucerne ,  Switzerland
# 3                                       Nice ,  France
# 4                                              Belgium
# ..                                                 ...
# 884                                                NaN
# 885                            Buenos Aires, Argentina
# 886                          Buenos Aires ,  Argentina
# 887                          Buenos Aires ,  Argentina
# 888                                                NaN
#
#                                                   text  year  award_age
# 0        César Milstein , Physiology or Medicine, 1984  1984         57
# 1    Ivo Andric *,  born in then  Austria–Hungary ,...  1961         69
# 2                      Auguste Beernaert , Peace, 1909  1909         80
# 3               Maurice Maeterlinck , Literature, 1911  1911         49
# 4                      Henri La Fontaine , Peace, 1913  1913         59
# ..                                                 ...   ...        ...
# 884  Brian P. Schmidt ,  born in the United States ...  2011         44
# 885                Carlos Saavedra Lamas , Peace, 1936  1936         58
# 886    Bernardo Houssay , Physiology or Medicine, 1947  1947         60
# 887             Luis Federico Leloir , Chemistry, 1970  1970         64
# 888                Adolfo Pérez Esquivel , Peace, 1980  1980         49
#
# [889 rows x 13 columns]

# %%
chart = alt.Chart(df)

# %%
gender_count = df['gender'].value_counts().reset_index()
gender_count.columns = ['gender', 'count']

# Altairで棒グラフを作成
chart = alt.Chart(gender_count).mark_bar().encode(
    x='gender:N',  # X軸にgender（カテゴリカルデータ）
    y='count:Q'    # Y軸にcount（数値データ）
)

# チャートを表示
chart.show()
# Out:
# alt.Chart(...)

# %%
# category と gender 列でグループ化し、各グループのサイズをカウント
grouped_data = df.groupby(['category', 'gender']).size().reset_index(name='count')

# Altairで棒グラフを作成（同じカテゴリ内で男女のバーを上下に並べる）
chart = alt.Chart(grouped_data).mark_bar().encode(
    y='category:N',    # Y軸にカテゴリ（category）
    x='count:Q',       # X軸にカウント（数値）
    color='gender:N',  # 性別（gender）で色分け
    row='gender:N'   # 性別ごとに別々の行に分けて表示
)

# チャートを表示
chart.show()
# Out:
# alt.Chart(...)

# %%
# "year" と "gender" でグループ化して人数をカウント
grouped_data = df.groupby(['year', 'gender']).size().reset_index(name='count')

# Altairで棒グラフを作成
chart = alt.Chart(grouped_data).mark_bar().encode(
    x='year:O',      # X軸: 年（年ごとに表示）
    y='count:Q',     # Y軸: 人数（カウント）
    color='gender:N', # 性別ごとに色分け
    row='gender:N'   # 性別ごとに別々の行に分けて表示
).properties(
    width=800,  # 各バーの幅
    height=400  # 高さ
)


# チャートを表示
chart.show()
# Out:
# alt.Chart(...)
